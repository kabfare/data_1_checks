# %% [markdown]
# Importing modules:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading in data:

# %%
df=pd.read_csv('Romance (1).csv')
df.head()
# Out:
#                                                  URL  \
# 0  http://api.scraperapi.com?api_key=a174547de4ed...
# 1  http://api.scraperapi.com?api_key=a174547de4ed...
# 2  http://api.scraperapi.com?api_key=a174547de4ed...
# 3  http://api.scraperapi.com?api_key=a174547de4ed...
# 4  http://api.scraperapi.com?api_key=a174547de4ed...
#
#                                                Title   Price  \
# 0  Kunex It Starts With Us + It Ends With Us: A N...  186.50
# 1  It Ends With Us : ''Sometimes The One Who Love...  229.00
# 2  Kunex It Starts With Us Paperback for Colleen ...  256.50
# 3                                 You Only Live Once  156.94
# 4  One Day, Life Will Change: A story of love and...  115.90
#
#    five_star_rating  four_star_rating  three_star_rating  two_star_rating  \
# 0              0.54              0.15               0.08             0.08
# 1              0.72              0.16               0.05             0.02
# ...

# %%
plt.title('Romance Books Ratings')
plt.xlabel('Book')
plt.ylabel('Rating')
plt.barh(df['Title'], df['overall_rating'])
# Out:
# <BarContainer object of 17 artists>
